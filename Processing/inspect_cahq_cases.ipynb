# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/home/nick/classwork_21_22/COMP755/COMP755FinalProj/Processing'

# %%
img = plt.imread('../../CelebAHQ256_normalized/00001.jpg_norm.png')

# %%
mask = plt.imread('../../CelebAHQ256_masks_pngs_for_gatedconv/00001.jpg_mask.png')

# %%
np.shape(mask)
# Out:
# (256, 256, 4)

# %%
plt.imshow(img)

# %%
plt.imshow(img*mask)

# %%
np.unique(mask)
# Out:
# array([0.00392157, 0.14117648, 0.26666668, 0.32941177, 0.90588236,
#        0.99215686, 1.        ], dtype=float32)

# %%
np.min(img), np.max(img)
# Out:
# (0.0, 1.0)

# %%
np.min(img*mask), np.max(img*mask)
# Out:
# (0.0, 1.0)

# %%
plt.imshow((img*mask * 255).astype(int))

# %%
plt.hist(np.reshape(mask[:,:,0], (-1)))
# Out:
# (array([28900.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#             0., 36636.]),
#  array([0.26666668, 0.3392157 , 0.4117647 , 0.48431373, 0.5568628 ,
#         0.62941176, 0.7019608 , 0.7745098 , 0.84705883, 0.9196078 ,
#         0.99215686], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
np.shape(mask)
# Out:
# (256, 256, 4)

# %%
np.shape(img)
# Out:
# (256, 256, 4)

# %%
plt.imshow(img[:,:,:3])

# %%
plt.imshow(mask[:,:])
